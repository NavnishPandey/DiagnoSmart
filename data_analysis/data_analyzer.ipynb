# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\giova\OneDrive\Documenti\DiagnoSmart\Dataset.csv")  
print(df.columns)
df.head()
# Out:
# Index(['Unnamed: 0', 'complaint', 'specialty', 'severity_level', 'chronic'], dtype='object')
#    Unnamed: 0                                          complaint  \
# 0           0  I'm a 27-year-old male. I have nasal obstructi...
# 1           1  I have constant My acne is getting worse despi...
# 2           2  I have mild I panic in crowds and can't leave ...
# 3           3  I have extreme My eye is red and feels like th...
# 4           4  I'm a 66-year-old male. I have occasionally jo...
#
#               specialty severity_level  chronic
# 0  ENT (Otolaryngology)       moderate    False
# 1           Dermatology           high     True
# 2            Psychiatry            low     True
# 3         Ophthalmology           high    False
# 4          Rheumatology            low     True

# %%
df['specialty'].value_counts()
# Out:
# specialty
# ENT (Otolaryngology)    333
# Dermatology             333
# Psychiatry              333
# Ophthalmology           333
# Rheumatology            333
# Pulmonology             333
# Cardiology              333
# Endocrinology           333
# Gastroenterology        333
# Urology                 333
# Orthopedics             333
# Neurology               333
# Name: count, dtype: int64

# %%
from collections import Counter
import re

def get_common_words_for_specialty(specialty, top_k=20):
    texts = df[df['specialty'] == specialty]['complaint']
    all_words = []
    for text in texts:
        words = re.findall(r'\b\w+\b', text.lower())
        all_words.extend(words)
    return Counter(all_words).most_common(top_k)

get_common_words_for_specialty('Orthopedics')
get_common_words_for_specialty('Neurology')
# Out:
# [('i', 839),
#  ('and', 463),
#  ('a', 433),
#  ('have', 367),
#  ('for', 278),
#  ('had', 204),
#  ('been', 164),
#  ('year', 162),
#  ('in', 152),
#  ('of', 135),
#  ('my', 113),
#  ('history', 109),
#  ('has', 107),
#  ('that', 106),
#  ('ve', 103),
#  ('m', 100),
#  ('old', 99),
#  ('frequent', 89),
#  ('weakness', 78),
#  ('tingling', 78)]

# %%
df[df['complaint'].str.contains("injury|headache|pain", case=False)]
# Out:
#       Unnamed: 0                                          complaint  \
# 4              4  I'm a 66-year-old male. I have occasionally jo...
# 12            12  I'm a 75-year-old male. I have minor facial pa...
# 21            21  I'm a 50-year-old male. I have minor facial pa...
# 22            22  I have frequent pain during intercourse and no...
# 23            23  I have somewhat pain in my lower back near my ...
# ...          ...                                                ...
# 3912        3912  I have excruciating I see blood in my urine fo...
# 3927        3927  I have constant wheezing that has been progres...
# 3969        3969           I have depression and mostly muscle pain
# 3994        3994  I have frequent redness and intermittent headache
# 3995        3995  I have minor My fingers get stiff and painful ...
#
#                  specialty severity_level  chronic
# 4             Rheumatology            low     True
# 12    ENT (Otolaryngology)            low     True
# 21    ENT (Otolaryngology)            low    False
# 22                 Urology       moderate    False
# 23                 Urology            low     True
# ...                    ...            ...      ...
# 3912               Urology           high     True
# 3927           Pulmonology           high    False
# 3969          Rheumatology       moderate    False
# 3994         Ophthalmology       moderate    False
# 3995           Orthopedics            low    False
#
# [590 rows x 5 columns]
